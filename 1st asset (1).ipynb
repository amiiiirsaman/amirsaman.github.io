# %%
import pandas as pd
import matplotlib.pyplot as plt
corona_economy = pd.read_csv('Section 1.csv')
print(corona_economy.head(2))
# Out:
#      year  month   day  Time  FL_new_case_count  FL_case_count  \
# 0  2020.0    2.0  24.0   1.0            -0.0246        -0.0234
# 1  2020.0    2.0  25.0   2.0            -0.0336        -0.0346
#
#    FL_new_death_count  FL_death_count  FL_new_test_count  FL_test_count  ...  \
# 0             -0.0647         -0.0125            0.00161        -0.0155  ...
# 1             -0.0593         -0.0174           -0.00616        -0.0212  ...
#
#    TX_gps_retail_and_recreation  TX_gps_grocery_and_pharmacy  TX_gps_parks  \
# 0                          0.01                      0.00000       -0.0400
# 1                          0.02                      0.00429       -0.0171
#
#    TX_gps_transit_stations  TX_gps_workplaces  TX_gps_residential  \
# 0                   0.0171             0.0229             0.00000
# 1                   0.0171             0.0257            -0.00143
#
#    TX_gps_away_from_home  TX_revenue_all  TX_merchants_all   TX_emp
# 0               0.000851          -0.021          -0.00204  0.00665
# 1               0.002250          -0.021          -0.00842  0.00670
#
# [2 rows x 99 columns]

# %%
corona_economy.describe()
# Out:
#               year       month         day        Time  FL_new_case_count  \
# count   436.000000  436.000000  436.000000  436.000000         436.000000
# mean   2020.284404    6.025229   15.752294  218.500000          -0.531472
# std       0.451648    3.369478    8.891588  126.006614           0.141007
# min    2020.000000    1.000000    1.000000    1.000000          -0.904000
# 25%    2020.000000    3.000000    8.000000  109.750000          -0.584000
# 50%    2020.000000    5.000000   16.000000  218.500000          -0.540500
# 75%    2021.000000    9.000000   24.000000  327.250000          -0.491000
# max    2021.000000   12.000000   31.000000  436.000000          -0.024600
#
#        FL_case_count  FL_new_death_count  FL_death_count  FL_new_test_count  \
# count     436.000000          436.000000      436.000000         436.000000
# mean       -0.541682           -0.200701       -0.272186          -0.281751
# std         0.143637            0.121044        0.080369           0.096259
# min        -0.912000           -0.540000       -0.492000          -0.505000
# 25%        -0.597000           -0.296250       -0.309000          -0.337250
# 50%        -0.548000           -0.181000       -0.275000          -0.275000
# 75%        -0.501000           -0.113750       -0.242000          -0.238750
# max        -0.023400            0.343000       -0.012500           0.001610
#
#        FL_test_count  ...  TX_gps_retail_and_recreation  \
# count     436.000000  ...                    437.000000
# mean       -0.255114  ...                     -0.169130
# std         0.084645  ...                      0.102504
# min        -0.519000  ...                     -0.484000
# 25%        -0.291000  ...                     -0.193000
# 50%        -0.263000  ...                     -0.167000
# 75%        -0.233750  ...                     -0.131000
# max         0.334000  ...                      0.107000
#
#        TX_gps_grocery_and_pharmacy  TX_gps_parks  TX_gps_transit_stations  \
# count                   437.000000    437.000000               437.000000
# mean                     -0.070523     -0.065348                -0.255623
# std                       0.060909      0.158243                 0.102189
# min                      -0.246000     -0.600000                -0.529000
# 25%                      -0.098600     -0.187000                -0.296000
# 50%                      -0.077100     -0.014300                -0.263000
# 75%                      -0.042900      0.042900                -0.231000
# max                       0.177000      0.280000                 0.060000
#
#        TX_gps_workplaces  TX_gps_residential  TX_gps_away_from_home  \
# count         437.000000          437.000000             437.000000
# mean           -0.291593            0.097174              -0.115292
# std             0.092911            0.042310               0.052828
# min            -0.616000           -0.018600              -0.257000
# 25%            -0.336000            0.075700              -0.140000
# 50%            -0.289000            0.094300              -0.112000
# 75%            -0.254000            0.117000              -0.088100
# max             0.028600            0.211000               0.025000
#
#        TX_revenue_all  TX_merchants_all      TX_emp
# count      437.000000        437.000000  437.000000
# mean        -0.301271         -0.280373   -0.102192
# std          0.104865          0.081514    0.037862
# min         -0.590000         -0.557000   -0.200000
# 25%         -0.362000         -0.322000   -0.115000
# 50%         -0.321000         -0.304000   -0.104000
# 75%         -0.256000         -0.263000   -0.092500
# max          0.005060         -0.002040    0.006700
#
# [8 rows x 99 columns]

# %%
import datetime

FL_covid_new_case = corona_economy['FL_new_case_count']
CA_covid_new_case = corona_economy['CA_new_case_count']
TX_covid_new_case = corona_economy['TX_new_case_count']

FL_spending = corona_economy['FL_spend_all']
CA_spending = corona_economy['CA_spend_all']
TX_spending = corona_economy['TX_spend_all']

FL_revenue = corona_economy['FL_revenue_all']
CA_revenue = corona_economy['CA_revenue_all']
TX_revenue = corona_economy['TX_revenue_all']

FL_merchant = corona_economy['FL_merchants_all']
CA_merchant = corona_economy['CA_merchants_all']
TX_merchant = corona_economy['TX_merchants_all']

FL_employment = corona_economy['FL_emp']
CA_employment = corona_economy['CA_emp']
TX_employment = corona_economy['TX_emp']

Time = corona_economy['Time']

FL_spending_apparel_accessories = corona_economy['FL_spend_aap']
FL_spending_accomodation_food_service = corona_economy['FL_spend_acf']
FL_spending_entertainment_recreation = corona_economy['FL_spend_aer']
FL_spending_grocery_food = corona_economy['FL_spend_grf']
FL_spending_general_merchandise = corona_economy['FL_spend_gen']
FL_spending_home_improvement = corona_economy['FL_spend_hic']
FL_spending_health_care = corona_economy['FL_spend_hcs']
FL_spending_sporting_goods = corona_economy['FL_spend_sgh']
FL_spending_transportation = corona_economy['FL_spend_tws']

# %%
plt.plot(Time, FL_covid_new_case)
plt.plot(Time, CA_covid_new_case)
plt.plot(Time, TX_covid_new_case)

plt.title('Impact of Covid 19 New Cases on Spending')
plt.xlabel('Covid New Cases')
plt.ylabel('Spending_all')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.scatter(CA_covid_new_case, CA_spending)
plt.xlabel('California New Covid19 Cases')
plt.ylabel('California Spendings')
plt.show()

# %%
FL = corona_economy[['FL_new_case_count', 'FL_spend_all', 'FL_revenue_all', 'FL_merchants_all', 'FL_emp','FL_spend_aap', 'FL_spend_acf','FL_spend_aer', 'FL_spend_grf', 'FL_spend_gen', 'FL_spend_hic', 'FL_spend_hcs', 'FL_spend_sgh']]
FL.corr()

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(16, 6))

mask = np.triu(np.ones_like(FL.corr(), dtype=np.bool))
heatmap = sns.heatmap(FL.corr(), mask=mask, vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Triangle Correlation Heatmap', fontdict={'fontsize':18}, pad=16);
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:10: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   # Remove the CWD from sys.path while we load stuff.

# %%
FL.corr()[['FL_new_case_count']].sort_values(by='FL_new_case_count', ascending=False)

plt.figure(figsize=(8, 12))

heatmap = sns.heatmap(FL.corr()[['FL_new_case_count']].sort_values(by='FL_new_case_count', ascending=False), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Features Correlating with FL new case counts', fontdict={'fontsize':18}, pad=16);
